# %% [markdown]
# # sklearn - sk.dataset to pandas
#
# sk datasets are split into *data*, *target*, *target_names*, *feature_names* ...
#
# - load sample sklearn dataset
# - access as
#     - bunch type (default), or
#     - pandas dataFrame
# - exploratory data analysis (EDA)

# %%
import sklearn as sk
from sklearn.datasets import load_iris
import pandas as pd

# %% [markdown]
# ## load

# %%
# load

# iris = sk.datasets.load_iris()
# iris = sk.datasets.load_iris().get("data")               # returns a bunch object
# data, target = sk.datasets.load_iris(return_X_y=True)    # returns a numpy array
# data  = sk.datasets.load_iris(return_X_y=True, as_frame=True) #returns as pandas dataframe, lost target_names

data, target = load_iris(return_X_y=True, as_frame=True)

print("data", type(data),
      "\ntarget", type(target))
# Out:
# data <class 'pandas.core.frame.DataFrame'>
# target <class 'pandas.core.series.Series'>

# %%
print(data.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# combine data & target as one dataframe

dfIris = pd.DataFrame(data=data)

dfIris["type"] = target

print(dfIris.tail().transpose())
# Out:
#                    145  146  147  148  149
# sepal length (cm)  6.7  6.3  6.5  6.2  5.9
# sepal width (cm)   3.0  2.5  3.0  3.4  3.0
# petal length (cm)  5.2  5.0  5.2  5.4  5.1
# petal width (cm)   2.3  1.9  2.0  2.3  1.8
# type               2.0  2.0  2.0  2.0  2.0

# %% [markdown]
# ### exploratory data analysis

# %%
pd.plotting.scatter_matrix(frame=dfIris,
                           figsize=(7,7))
# Out:
# array([[<Axes: xlabel='sepal length (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='type', ylabel='sepal length (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='type', ylabel='sepal width (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='type', ylabel='petal length (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='petal width (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='petal width (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='petal width (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='petal width (cm)'>,
#         <Axes: xlabel='type', ylabel='petal width (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='type'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='type'>,
#         <Axes: xlabel='petal length (cm)', ylabel='type'>,
#         <Axes: xlabel='petal width (cm)', ylabel='type'>,
#         <Axes: xlabel='type', ylabel='type'>]], dtype=object)
